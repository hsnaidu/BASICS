# %% [markdown]
# * Impt. always use [[ ]], >>  [['column_1', 'column_2']], Gives value in Dataframe

# %%
from sys import version
print(version)

# Print the Panda-Version
import pandas 
print("🐼 Version : ",pandas.__version__)
# Out:
# 3.11.7 | packaged by Anaconda, Inc. | (main, Dec 15 2023, 18:05:47) [MSC v.1916 64 bit (AMD64)]
# 🐼 Version :  2.2.2

# %% [markdown]
# Learning Pandas : 🐼 Fast : ⚡

# %%
import pandas as pd
pd.set_option('display.max_columns', 500) # Avoids the column overwrite

# %% [markdown]
# 1. Inputting Data

# %%
df = pd.read_excel('Flight_Data.xlsx')
type(df) # checking the type
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# To save the data to csv, excel

# %%
df.to_csv('Test_Save_to_csv.csv', index=False )
df.to_csv('Test_Save_to_excel.xlsx', index=False )

# %% [markdown]
# * Data Frame Basics

# %% [markdown]
# Head

# %%
# 1. Head : First 5 Rows of your dataset
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %% [markdown]
# Tail

# %%
# 2. Tail : Last 5 Rows of your dataset
df.tail()
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time Arrival_Time Duration Total_Stops  \
# 10678              CCU → BLR    19:55        22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45        23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20        11:20       3h    non-stop
# 10681              BLR → DEL    11:30        14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55        19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753

# %% [markdown]
# Impt. Explore your data Random'ly by taking SAMPLE

# %%
df.sample(5, random_state= 143)
# 5 - Number of rows , Can also give frac = 0.1  

# The data taken here is very random..
# Out:
#                 Airline Date_of_Journey   Source Destination  \
# 6257          Air India      21/05/2019  Kolkata    Banglore
# 3502        Jet Airways       9/05/2019  Kolkata    Banglore
# 7572  Multiple carriers      21/05/2019    Delhi      Cochin
# 2158        Jet Airways      27/03/2019   Mumbai   Hyderabad
# 8568        Jet Airways       3/06/2019    Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 6257              CCU → BLR    14:15         16:45   2h 30m    non-stop
# 3502        CCU → BOM → BLR    21:10  12:00 10 May  14h 50m      1 stop
# 7572        DEL → BOM → COK    10:35         19:00   8h 25m      1 stop
# 2158              BOM → HYD    07:10         08:35   1h 25m    non-stop
# 8568  DEL → JAI → BOM → COK    19:30  12:35 04 Jun   17h 5m     2 stops
#
#                   Additional_Info  Price
# 6257                      No info   5510
# 3502  In-flight meal not included   9663
# ...

# %% [markdown]
# Columns and Index

# %%
df.columns, df.index
# Out:
# (Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#         'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#         'Additional_Info', 'Price'],
#        dtype='object'),
#  RangeIndex(start=0, stop=10683, step=1))

# %% [markdown]
# Info : To Give the information of the dataset

# %%
df.info()
# Also shows the summary..
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %% [markdown]
# df.info(verbose = False)

# %%
df.info(verbose= False)
# This is also a very quick summary of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Columns: 11 entries, Airline to Price
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %% [markdown]
# Describe : Provides the stat values of all int data

# %%
df.describe()
# Only Price is there as of now, cause we have not explored Object
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %% [markdown]
# Describe will also work for non-int columns

# %%
df[['Airline']].describe()
# Out:
#             Airline
# count         10683
# unique           12
# top     Jet Airways
# freq           3849

# %% [markdown]
# Shape : Shows the number of Rows and Column, size : column * rows

# %%
df.shape, df.size
# Out:
# ((10683, 11), 117513)

# %% [markdown]
# Subsetting a Dataset

# %%
df[['Airline','Source','Destination']].head()
# Out:
#        Airline    Source Destination
# 0       IndiGo  Banglore   New Delhi
# 1    Air India   Kolkata    Banglore
# 2  Jet Airways     Delhi      Cochin
# 3       IndiGo   Kolkata    Banglore
# 4       IndiGo  Banglore   New Delhi

# %% [markdown]
# You can even use columns

# %%
# df.columns

# You can use
df[df.columns[:3]].head() # First 3 Columns
df[df.columns[-5:]].head() # Last 5 Columns
# Out:
#    Arrival_Time Duration Total_Stops Additional_Info  Price
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1         13:15   7h 25m     2 stops         No info   7662
# 2  04:25 10 Jun      19h     2 stops         No info  13882
# 3         23:30   5h 25m      1 stop         No info   6218
# 4         21:35   4h 45m      1 stop         No info  13302

# %% [markdown]
# List Itteration

# %%
[x for x in df.columns if 'Source' in x] # I can search columns in this ..

# Filtering only Source
# Out:
# ['Source']

# %% [markdown]
# Filter by Just usig the dtypes

# %%
df.select_dtypes('int').head(1)
# Gives the column only with the integer
# Out:
#    Price
# 0   3897

# %% [markdown]
# Series vs Dataframe : Subset in data

# %%
df['Airline'].head(2), type(df['Airline'])
# This gives in Series
# Out:
# (0       IndiGo
#  1    Air India
#  Name: Airline, dtype: object,
#  pandas.core.series.Series)

# %%
df[['Airline']].head(2), type(df[['Airline']])
# This gives in Dataframe
# Out:
# (     Airline
#  0     IndiGo
#  1  Air India,
#  pandas.core.frame.DataFrame)

# %% [markdown]
# Lets Play with Rows
#
# * Filtering ROWS using iloc[ ] and loc[ ]

# %% [markdown]
# * Both Allows you to acces data from the dataframe

# %% [markdown]
# 1. iloc[ ] : Gives access to index-values
# 2. loc[ ] : Gives access to the names

# %%
# Example
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662

# %% [markdown]
# iloc

# %%
# Assume I need New Delhi

# df.iloc[# Row, # Column]

df.iloc[0, 3] # Gives me New-Delhi
df.iloc[:3, 3] # Also works with slicing
# Out:
# 0    New Delhi
# 1     Banglore
# 2       Cochin
# Name: Destination, dtype: object

# %% [markdown]
# loc

# %%
# Using Loc you provind the column names

# This is used moreee

# df.loc[ #Rows, #[column_1, column_2]]

df.loc[: ,['Airline', 'Source']].head()
# Out:
#        Airline    Source
# 0       IndiGo  Banglore
# 1    Air India   Kolkata
# 2  Jet Airways     Delhi
# 3       IndiGo   Kolkata
# 4       IndiGo  Banglore

# %% [markdown]
# Boolean Expression

# %%
df[df['Airline'] == 'IndiGo'] # Returns me all the rows that has 'IndiGo'
# Out:
#       Airline Date_of_Journey    Source Destination            Route Dep_Time  \
# 0      IndiGo      24/03/2019  Banglore   New Delhi        BLR → DEL    22:20
# 3      IndiGo      12/05/2019   Kolkata    Banglore  CCU → NAG → BLR    18:05
# 4      IndiGo      01/03/2019  Banglore   New Delhi  BLR → NAG → DEL    16:50
# 11     IndiGo      18/04/2019   Kolkata    Banglore        CCU → BLR    20:20
# 14     IndiGo      24/04/2019   Kolkata    Banglore        CCU → BLR    17:15
# ...       ...             ...       ...         ...              ...      ...
# 10631  IndiGo      15/05/2019     Delhi      Cochin  DEL → BLR → COK    02:00
# 10641  IndiGo       6/03/2019   Chennai     Kolkata        MAA → CCU    07:55
# 10649  IndiGo       1/03/2019   Kolkata    Banglore        CCU → BLR    21:25
# 10664  IndiGo       9/04/2019  Banglore       Delhi        BLR → DEL    18:55
# 10665  IndiGo      27/04/2019   Kolkata    Banglore        CCU → BLR    15:15
#
# ...

# %% [markdown]
# Combining the Boolean Expression

# %%
df[(df['Airline'] == 'IndiGo') &
   (df['Date_of_Journey'] == '24/03/2019')]

# Play with & or ||
# Out:
#       Airline Date_of_Journey    Source Destination      Route Dep_Time  \
# 0      IndiGo      24/03/2019  Banglore   New Delhi  BLR → DEL    22:20
# 52     IndiGo      24/03/2019  Banglore   New Delhi  BLR → DEL    22:20
# 161    IndiGo      24/03/2019  Banglore   New Delhi  BLR → DEL    00:40
# 328    IndiGo      24/03/2019  Banglore   New Delhi  BLR → DEL    18:25
# 703    IndiGo      24/03/2019   Kolkata    Banglore  CCU → BLR    20:25
# ...       ...             ...       ...         ...        ...      ...
# 9493   IndiGo      24/03/2019   Chennai     Kolkata  MAA → CCU    13:20
# 9844   IndiGo      24/03/2019  Banglore   New Delhi  BLR → DEL    21:20
# 10047  IndiGo      24/03/2019   Chennai     Kolkata  MAA → CCU    22:05
# 10162  IndiGo      24/03/2019  Banglore   New Delhi  BLR → DEL    22:20
# 10204  IndiGo      24/03/2019   Kolkata    Banglore  CCU → BLR    05:30
#
#        Arrival_Time Duration Total_Stops Additional_Info  Price
# ...

# %% [markdown]
# If you want inverse of this add a ~

# %%
df[~(df['Airline'] == 'IndiGo') &
   (df['Date_of_Journey'] == '24/03/2019')]

# Gives me Everything apart from the IndiGo on that date
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 45        SpiceJet      24/03/2019  Banglore   New Delhi
# 55     Jet Airways      24/03/2019   Kolkata    Banglore
# 81     Jet Airways      24/03/2019  Banglore   New Delhi
# 200          GoAir      24/03/2019   Kolkata    Banglore
# 230      Air India      24/03/2019   Kolkata    Banglore
# ...            ...             ...       ...         ...
# 10542  Jet Airways      24/03/2019   Kolkata    Banglore
# 10590     Air Asia      24/03/2019  Banglore   New Delhi
# 10626        GoAir      24/03/2019  Banglore   New Delhi
# 10630  Jet Airways      24/03/2019   Kolkata    Banglore
# 10662    Air India      24/03/2019   Kolkata    Banglore
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 45                 BLR → DEL    05:45         08:35   2h 50m    non-stop
# 55           CCU → BOM → BLR    19:45  12:00 25 Mar  16h 15m      1 stop
# ...

# %%
df['Date_of_Journey'].dtype
# Out:
# dtype('O')

# %% [markdown]
# You can also use the Query method

# %% [markdown]
# Check for Quotation marks the searching values must be quoted " " if its string

# %%
df.query('Airline == "Jet Airways" &  Date_of_Journey == "24/03/2019"').head(2)
# Out:
#         Airline Date_of_Journey    Source Destination            Route  \
# 55  Jet Airways      24/03/2019   Kolkata    Banglore  CCU → BOM → BLR
# 81  Jet Airways      24/03/2019  Banglore   New Delhi        BLR → DEL
#
#    Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 55    19:45  12:00 25 Mar  16h 15m      1 stop         No info  14231
# 81    19:55         22:35   2h 40m    non-stop         No info   7229

# %% [markdown]
# If you need to access and External variable use '@'

# %%
min_price = df['Price'].min()

df.query('Price == @min_price')['Airline']
# Out:
# 4066     SpiceJet
# 4274     SpiceJet
# 4839     SpiceJet
# 10513    SpiceJet
# Name: Airline, dtype: object

# %% [markdown]
# Summarizing My Data

# %% [markdown]
# They Basically-use all stat methods

# %%
from statistics import mode
print("Min Value")
print(df['Price'].min())
print("Max Value")
print(df['Price'].max())
print("Avg Value")
print(df['Price'].mean())
print("Median Value")
print(df['Price'].median())
print("Mode Value")
print('For this you need import statistics library')
print(mode(df['Price']))
print("Quartile")
print(df['Price'].quantile(0.10))
print("Standard Deviation")
print(df['Price'].std())
print("Variance")
print(df['Price'].var())
print('Count')
print(df['Price'].count())
print("Sum")
print(df['Price'].sum())
# Out:
# Min Value
# 1759
# Max Value
# 79512
# Avg Value
# 9087.064120565385
# Median Value
# 8372.0
# Mode Value
# For this you need import statistics library
# 10262
# Quartile
# 3943.0
# Standard Deviation
# 4611.35916681709
# Variance
# 21264633.365388006
# Count
# 10683
# Sum
# 97077106

# %% [markdown]
# APPLY

# %% [markdown]
# If you want to apply a set of operation or a custom function you can use APPLY

# %%
import numpy as np
from statistics import mode

df['Price'].apply([np.mean, np.median, lambda x :mode(x)])
# x is col-- passing col to x on lambda
# Out:
# mean         9087.064121
# median       8372.000000
# <lambda>    10262.000000
# Name: Price, dtype: float64

# %% [markdown]
# Unique Values

# %%
df['Airline'].unique()
# Gives me all the unique values..
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %% [markdown]
# Nunique

# %%
df['Airline'].nunique()
# Gives me the number of unique value
# Out:
# 12

# %% [markdown]
# Value_Counts -- Very Important

# %%
df['Airline'].value_counts(ascending=True)

# I can get the Normalized value as well ..
# Out:
# Airline
# Trujet                                  1
# Vistara Premium economy                 3
# Jet Airways Business                    6
# Multiple carriers Premium economy      13
# GoAir                                 194
# Air Asia                              319
# Vistara                               479
# SpiceJet                              818
# Multiple carriers                    1196
# Air India                            1752
# IndiGo                               2053
# Jet Airways                          3849
# Name: count, dtype: int64

# %%
df['Airline'].value_counts(normalize=True)
# Out:
# Airline
# Jet Airways                          0.360292
# IndiGo                               0.192174
# Air India                            0.163999
# Multiple carriers                    0.111954
# SpiceJet                             0.076570
# Vistara                              0.044838
# Air Asia                             0.029861
# GoAir                                0.018160
# Multiple carriers Premium economy    0.001217
# Jet Airways Business                 0.000562
# Vistara Premium economy              0.000281
# Trujet                               0.000094
# Name: proportion, dtype: float64

# %% [markdown]
# Reset_index()

# %%
df[['Airline','Price']].value_counts().reset_index().head()

# NOTE : you can do above or below 

# df.groupby(['Airline', 'Price']).size().reset_index()
# Out:
#        Airline  Price  count
# 0  Jet Airways  10262    258
# 1  Jet Airways  10844    212
# 2  Jet Airways   7229    162
# 3       IndiGo   4804    160
# 4       IndiGo   4823    131

# %% [markdown]
# Groupby Methods

# %% [markdown]
# These are very Important to deal with the categorical types

# %%
df.groupby(['Airline','Price']).size().reset_index().rename(columns={0 : 'Count'})
# Out:
#                       Airline  Price  Count
# 0                    Air Asia   3383     31
# 1                    Air Asia   3782      4
# 2                    Air Asia   3807     19
# 3                    Air Asia   4082      3
# 4                    Air Asia   4107     11
# ...                       ...    ...    ...
# 1973                  Vistara  21520      1
# 1974                  Vistara  21730      2
# 1975  Vistara Premium economy   5969      1
# 1976  Vistara Premium economy   9125      1
# 1977  Vistara Premium economy  11793      1
#
# [1978 rows x 3 columns]

# %%
min_array = df.groupby(['Airline'])['Price'].min()
max_array = df.groupby(['Airline'])['Price'].max()

pd.merge(min_array, max_array, suffixes=['_min_plane_value','_max_plane_value'] ,on='Airline', how='right').tail(10)
# Out:
#                                    Price_min_plane_value  \
# Airline
# GoAir                                               3398
# IndiGo                                              2227
# Jet Airways                                         1840
# Jet Airways Business                               46490
# Multiple carriers                                   5797
# Multiple carriers Premium economy                   9845
# SpiceJet                                            1759
# Trujet                                              4140
# Vistara                                             3687
# Vistara Premium economy                             5969
#
#                                    Price_max_plane_value
# Airline
# GoAir                                              22794
# IndiGo                                             22153
# Jet Airways                                        54826
# Jet Airways Business                               79512
# ...

# %% [markdown]
# Creating a New-Column

# %%
df['New_Col'] = ['1' if x > df['Price'].min() else '0' for x in df['Price']]

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price', 'New_Col'],
#       dtype='object')

# %%
df['New_Col'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: New_Col, dtype: object

# %% [markdown]
# Sorting your data

# %%
df.sort_values('Price', ascending=True).reset_index(drop=True).head(3)
# Do this instead of 

# df.sort_values('Price', ascending=True).reset_index().head(3).drop(columns=['index'])
# Out:
#     Airline Date_of_Journey  Source Destination      Route Dep_Time  \
# 0  SpiceJet      21/03/2019  Mumbai   Hyderabad  BOM → HYD    22:45
# 1  SpiceJet      27/03/2019  Mumbai   Hyderabad  BOM → HYD    05:45
# 2  SpiceJet       3/04/2019  Mumbai   Hyderabad  BOM → HYD    22:45
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price New_Col
# 0  00:10 22 Mar   1h 25m    non-stop         No info   1759       0
# 1         07:05   1h 20m    non-stop         No info   1759       0
# 2  00:15 02 Apr   1h 30m    non-stop         No info   1759       0

# %%
df.sort_index(axis=0)
# This sorts in Alphabetic order..
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %% [markdown]
# Missing Data

# %%
df.isna().head(1)
# Out:
#    Airline  Date_of_Journey  Source  Destination  Route  Dep_Time  \
# 0    False            False   False        False  False     False
#
#    Arrival_Time  Duration  Total_Stops  Additional_Info  Price  New_Col
# 0         False     False        False            False  False    False

# %% [markdown]
# A Count of all the missing values

# %%
df.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# New_Col            0
# dtype: int64

# %% [markdown]
# Filling the missing values

# %%
df.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# New_Col            0
# dtype: int64

# %%
df.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\harip\AppData\Local\Temp\ipykernel_17740\3970806690.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %%
df.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# New_Col            0
# dtype: int64

# %% [markdown]
# Concat Method

# %%
df1 = df[df['Airline'] == "IndiGo"].copy()
df2 = df[df['Airline'] == "Jet Airways"].copy()

# %%
print(df1.shape, df2.shape)
# Out:
# (2053, 12) (3849, 12)

# %% [markdown]
# Make a DataFrame using the Query

# %%
df.query('Airline == "Jet Airways" or Airline == "IndiGo"').sort_index(axis=0).reset_index(drop=True)
# Out:
#           Airline Date_of_Journey    Source Destination  \
# 0          IndiGo      24/03/2019  Banglore   New Delhi
# 1     Jet Airways       9/06/2019     Delhi      Cochin
# 2          IndiGo      12/05/2019   Kolkata    Banglore
# 3          IndiGo      01/03/2019  Banglore   New Delhi
# 4     Jet Airways      12/03/2019  Banglore   New Delhi
# ...           ...             ...       ...         ...
# 5897  Jet Airways       9/05/2019     Delhi      Cochin
# 5898  Jet Airways      27/06/2019     Delhi      Cochin
# 5899  Jet Airways      27/05/2019     Delhi      Cochin
# 5900  Jet Airways      12/03/2019  Banglore   New Delhi
# 5901  Jet Airways      27/04/2019  Banglore       Delhi
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 2           CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# ...

# %%
pd.concat([df1, df2], ignore_index= True)
# It stacks one below the other
# Out:
#           Airline Date_of_Journey    Source Destination  \
# 0          IndiGo      24/03/2019  Banglore   New Delhi
# 1          IndiGo      12/05/2019   Kolkata    Banglore
# 2          IndiGo      01/03/2019  Banglore   New Delhi
# 3          IndiGo      18/04/2019   Kolkata    Banglore
# 4          IndiGo      24/04/2019   Kolkata    Banglore
# ...           ...             ...       ...         ...
# 5897  Jet Airways       9/05/2019     Delhi      Cochin
# 5898  Jet Airways      27/06/2019     Delhi      Cochin
# 5899  Jet Airways      27/05/2019     Delhi      Cochin
# 5900  Jet Airways      12/03/2019  Banglore   New Delhi
# 5901  Jet Airways      27/04/2019  Banglore       Delhi
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1           CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 2           BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...

# %% [markdown]
# Merging the data

# %%
df1 = pd.DataFrame({
    'Index' : [x for x in range(5)],
    'New_index_One' : [x for x in range(10) if x%2 == 0]
})
df2 = pd.DataFrame({
    'Index' : [x for x in range(5)],
    'New_index_Two' : [~x for x in range(10) if x%2 != 0] # Neg becuase I have added ~
})

# %% [markdown]
# Also adding the suffixes..

# %%
df3 = pd.merge(df1, df2, on='Index', how='right', 
               suffixes=['_one','_two']).reset_index(drop=True).drop(columns='Index')

# You can also add SUFFIXES

# %%
df3
# Out:
#    New_index_One  New_index_Two
# 0              0             -2
# 1              2             -4
# 2              4             -6
# 3              6             -8
# 4              8            -10

# %%
import pandas as pd
df = pd.read_excel('Flight_Data.xlsx')
